# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_movies.CSV")

# %%
data.head()
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
data.shape
# Out:
# (9957, 9)

# %%
list(data.columns)
# Out:
# ['title',
#  'year',
#  'certificate',
#  'duration',
#  'genre',
#  'rating',
#  'description',
#  'stars',
#  'votes']

# %%
data.describe()
# Out:
#             rating
# count  8784.000000
# mean      6.764515
# std       1.214840
# min       1.700000
# 25%       6.100000
# 50%       6.900000
# 75%       7.600000
# max       9.900000

# %%
data.isnull()
# Out:
#       title   year  certificate  duration  genre  rating  description  stars  \
# 0     False  False        False     False  False   False        False  False
# 1     False  False        False     False  False   False        False  False
# 2     False  False        False     False  False   False        False  False
# 3     False  False        False     False  False   False        False  False
# 4     False  False        False     False  False   False        False  False
# 5     False  False        False     False  False   False        False  False
# 6     False  False        False     False  False   False        False  False
# 7     False  False        False     False  False   False        False  False
# 8     False  False        False     False  False   False        False  False
# 9     False  False        False     False  False   False        False  False
# 10    False  False        False     False  False   False        False  False
# ...

# %%
data1 = data[["title","rating","genre","year"]]

# %%
data1.head(20)
# Out:
#                                 title  rating                         genre  \
# 0                           Cobra Kai     8.5         Action, Comedy, Drama
# 1                           The Crown     8.7     Biography, Drama, History
# 2                    Better Call Saul     8.9                  Crime, Drama
# 3                       Devil in Ohio     5.9        Drama, Horror, Mystery
# 4              Cyberpunk: Edgerunners     8.6  Animation, Action, Adventure
# 5                         The Sandman     7.8        Drama, Fantasy, Horror
# 6                      Rick and Morty     9.2  Animation, Adventure, Comedy
# 7                        Breaking Bad     9.5        Crime, Drama, Thriller
# 8                      The Imperfects     6.3      Action, Adventure, Drama
# 9                              Blonde     6.2     Biography, Drama, Mystery
# 10                    Stranger Things     8.7        Drama, Fantasy, Horror
# ...

# %%
print(data1["rating"].unique())
# Out:
# [8.5 8.7 8.9 5.9 8.6 7.8 9.2 9.5 6.3 6.2 4.7 8.1 6.4 6.1 5.8 9.6 8.8 6.9
#  7.6 8.4 8.  7.4 6.5 5.  8.2 7.9 6.8 5.3 9.  7.1 7.3 nan 7.7 8.3 7.5 6.6
#  3.3 9.1 6.7 5.4 2.7 7.2 7.  2.6 9.3 5.7 4.3 5.5 4.9 5.2 4.  5.1 4.5 5.6
#  4.8 4.4 6.  3.9 4.1 4.2 2.8 3.5 3.8 4.6 3.6 3.7 2.9 3.2 3.4 3.1 2.3 2.5
#  9.4 2.1 3.  2.2 2.  1.7 2.4 9.9]

# %%
data1["rating"].value_counts()
# Out:
# 7.2    348
# 7.4    329
# 7.1    319
# 7.6    305
# 6.8    300
# 7.3    295
# 6.5    290
# 7.5    290
# 6.6    289
# 7.7    278
# 7.0    278
# 6.7    265
# 7.8    259
# 6.9    257
# 6.4    249
# 6.3    239
# 7.9    230
# 6.2    230
# 8.0    199
# 6.1    194
# 5.9    191
# 8.2    190
# 8.1    190
# 5.8    170
# 5.7    155
# 5.5    148
# 5.4    144
# 5.6    144
# 8.3    141
# 8.4    138
#       ...
# 4.2     30
# 9.1     28
# 3.9     26
# 4.0     23
# 3.7     23
# 4.1     21
# 3.6     20
# 3.5     19
# 3.4     19
# 3.1     18
# 3.3     16
# 9.2     15
# 3.2     12
# 9.3     11
# 9.4     11
# 2.5      8
# 2.7      8
# 2.8      7
# 9.5      7
# 9.6      6
# 2.6      5
# 2.3      5
# 2.9      4
# 3.0      3
# 2.2      3
# 2.0      2
# 2.1      2
# 2.4      1
# 1.7      1
# 9.9      1
# Name: rating, Length: 79, dtype: int64

# %%
data1.loc[(data1.rating == 8.4)]
# Out:
#                                    title  rating  \
# 22                          Supernatural     8.4
# 44                    Brooklyn Nine-Nine     8.4
# 47                             Outlander     8.4
# 56                         Sex Education     8.4
# 110                 Love, Death & Robots     8.4
# 115                             Billions     8.4
# 136                            Heartland     8.4
# 144                           Doc Martin     8.4
# 146       Star Trek: The Original Series     8.4
# 150                        The Good Wife     8.4
# 174            Star Wars: The Clone Wars     8.4
# 179             JoJo's Bizarre Adventure     8.4
# 181                 American Crime Story     8.4
# 186                        The Americans     8.4
# 207                           After Life     8.4
# 227                                 Maid     8.4
# 230                              Top Boy     8.4
# 242                               Naruto     8.4
# ...

# %%
print(data1["rating"].unique())
# Out:
# [8.5 8.7 8.9 5.9 8.6 7.8 9.2 9.5 6.3 6.2 4.7 8.1 6.4 6.1 5.8 9.6 8.8 6.9
#  7.6 8.4 8.  7.4 6.5 5.  8.2 7.9 6.8 5.3 9.  7.1 7.3 nan 7.7 8.3 7.5 6.6
#  3.3 9.1 6.7 5.4 2.7 7.2 7.  2.6 9.3 5.7 4.3 5.5 4.9 5.2 4.  5.1 4.5 5.6
#  4.8 4.4 6.  3.9 4.1 4.2 2.8 3.5 3.8 4.6 3.6 3.7 2.9 3.2 3.4 3.1 2.3 2.5
#  9.4 2.1 3.  2.2 2.  1.7 2.4 9.9]

# %%
data1["rating"].value_counts()
# Out:
# 7.2    348
# 7.4    329
# 7.1    319
# 7.6    305
# 6.8    300
# 7.3    295
# 6.5    290
# 7.5    290
# 6.6    289
# 7.7    278
# 7.0    278
# 6.7    265
# 7.8    259
# 6.9    257
# 6.4    249
# 6.3    239
# 7.9    230
# 6.2    230
# 8.0    199
# 6.1    194
# 5.9    191
# 8.2    190
# 8.1    190
# 5.8    170
# 5.7    155
# 5.5    148
# 5.4    144
# 5.6    144
# 8.3    141
# 8.4    138
#       ...
# 4.2     30
# 9.1     28
# 3.9     26
# 4.0     23
# 3.7     23
# 4.1     21
# 3.6     20
# 3.5     19
# 3.4     19
# 3.1     18
# 3.3     16
# 9.2     15
# 3.2     12
# 9.3     11
# 9.4     11
# 2.5      8
# 2.7      8
# 2.8      7
# 9.5      7
# 9.6      6
# 2.6      5
# 2.3      5
# 2.9      4
# 3.0      3
# 2.2      3
# 2.0      2
# 2.1      2
# 2.4      1
# 1.7      1
# 9.9      1
# Name: rating, Length: 79, dtype: int64

# %%
data1.loc[(data.rating == 8.1) & (data1.year=="2005–2020")]
# Out:
# Empty DataFrame
# Columns: [title, rating, genre, year]
# Index: []

# %%
data1.iloc[2]
# Out:
# title     Better Call Saul
# rating                 8.9
# genre         Crime, Drama
# year           (2015–2022)
# Name: 2, dtype: object

# %%
data1.iloc[4:10,:2]
# Out:
#                     title  rating
# 4  Cyberpunk: Edgerunners     8.6
# 5             The Sandman     7.8
# 6          Rick and Morty     9.2
# 7            Breaking Bad     9.5
# 8          The Imperfects     6.3
# 9                  Blonde     6.2

# %%
data2 = data[["title","rating","genre","year","votes"]]

# %%
list(data2.columns)
# Out:
# ['title', 'rating', 'genre', 'year', 'votes']

# %%
del.data1(rating)
# Out:
#   File "<ipython-input-20-e9b3ebb78f70>", line 1
#     del.data1(rating)
#        ^
# SyntaxError: invalid syntax

# %%
data2.drop(labels='rating', axis=1)

# %%
"axis = 1 means column, and axis = 0 for row"

# %%
list(data.columns)

# %%
data.drop(labels=['certificate','stars'], axis=1)

# %%
import numpy as np

# %%
data2.sort_values("rating", ascending= False)
