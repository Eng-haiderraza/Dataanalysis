# %%
import pandas as pd

# %%
data = pd.read_csv("PakistanDroneAttacksWithTemp Ver 11 (November 30 2017).csv", encoding = "latin 1")

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data.head()
# Out:
#     S#                         Date   Time  \
# 0  1.0        Friday, June 18, 2004  22:00
# 1  2.0         Sunday, May 08, 2005  23:30
# 2  3.0  Thursday, December 01, 2005    NaN
# 3  4.0     Friday, January 06, 2006    NaN
# 4  5.0     Friday, January 13, 2006   3:00
#
#                                Location              City Province  \
# 0                             Near Wana  south Waziristan     FATA
# 1          Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                   Haisori- Miran Shah  North Waziristan     FATA
# 3  Saidgai village- 115km north of Wana  North Waziristan     FATA
# 4                      Damadola Village    Bajaur  Agency     FATA
#
#    No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 0           1.0       NaN      1.0            0.0  ...          NaN
# 1           1.0       1.0      NaN            0.0  ...          NaN
# 2           1.0       1.0      NaN            0.0  ...          NaN
# ...

# %%
data['Date'] = data['Date'].str.strip()
data['Date'] = data['Date'].str.replace(',', '-')
data['year'] = pd.DatetimeIndex(data['Date']).year

# %%
data1 = data.rename({'Al-Qaeda': 'AlQaeda'}, axis=1 , inplace = True)

# %%
data.head()
# Out:
#     S#                         Date   Time  \
# 0  1.0        Friday- June 18- 2004  22:00
# 1  2.0         Sunday- May 08- 2005  23:30
# 2  3.0  Thursday- December 01- 2005    NaN
# 3  4.0     Friday- January 06- 2006    NaN
# 4  5.0     Friday- January 13- 2006   3:00
#
#                                Location              City Province  \
# 0                             Near Wana  south Waziristan     FATA
# 1          Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                   Haisori- Miran Shah  North Waziristan     FATA
# 3  Saidgai village- 115km north of Wana  North Waziristan     FATA
# 4                      Damadola Village    Bajaur  Agency     FATA
#
#    No of Strike  AlQaeda  Taliban  Civilians Min  ...  Injured Max  \
# 0           1.0      NaN      1.0            0.0  ...          NaN
# 1           1.0      1.0      NaN            0.0  ...          NaN
# 2           1.0      1.0      NaN            0.0  ...          2.0
# ...

# %%
data.isnull().sum()
# Out:
# S#                          1
# Date                        1
# Time                      231
# Location                    2
# City                        1
# Province                    1
# No of Strike                1
# AlQaeda                   308
# Taliban                   264
# Civilians Min              69
# Civilians Max              46
# Foreigners Min            312
# Foreigners Max            265
# Total Died Min             97
# Total Died Max              3
# Injured Min               260
# Injured Max               129
# Women/Children             69
# Special Mention (Site)     75
# Comments                  229
# References                  7
# Longitude                   1
# Latitude                    1
# Temperature(C)              2
# Temperature(F)              2
# year                        1
# dtype: int64

# %%
data.notnull().sum()
# Out:
# S#                        405
# Date                      405
# Time                      175
# Location                  404
# City                      405
# Province                  405
# No of Strike              405
# AlQaeda                    98
# Taliban                   142
# Civilians Min             337
# Civilians Max             360
# Foreigners Min             94
# Foreigners Max            141
# Total Died Min            309
# Total Died Max            403
# Injured Min               146
# Injured Max               277
# Women/Children            337
# Special Mention (Site)    331
# Comments                  177
# References                399
# Longitude                 405
# Latitude                  405
# Temperature(C)            404
# Temperature(F)            404
# year                      405
# dtype: int64

# %%
data['year'].isna().sum()
# Out:
# 1

# %%
# Out:
# 1

# %%
data['year'] = data['year'].fillna(0)
data[data['year'].isna()]
# Out:
# Empty DataFrame
# Columns: [S#, Date, Time, Location, City, Province, No of Strike, AlQaeda, Taliban, Civilians Min, Civilians Max, Foreigners Min, Foreigners Max, Total Died Min, Total Died Max, Injured Min, Injured Max, Women/Children  , Special Mention (Site), Comments, References, Longitude, Latitude, Temperature(C), Temperature(F), year]
# Index: []
#
# [0 rows x 26 columns]

# %%
data[data['year'] == 0 ]
# Out:
#      S# Date Time Location City Province  No of Strike  AlQaeda  Taliban  \
# 405 NaN  NaN  NaN      NaN  NaN      NaN           NaN     49.0    663.0
#
#      Civilians Min  ...  Injured Max  Women/Children    \
# 405         1306.0  ...       1329.0               NaN
#
#      Special Mention (Site)  Comments  References  Longitude  Latitude  \
# 405                     NaN       NaN         NaN        NaN       NaN
#
#     Temperature(C) Temperature(F) year
# 405            NaN            NaN  0.0
#
# [1 rows x 26 columns]

# %%
data = data.drop(data[data['year'] == 0].index)
data[data['year'] == 0 ]
# Out:
# Empty DataFrame
# Columns: [S#, Date, Time, Location, City, Province, No of Strike, AlQaeda, Taliban, Civilians Min, Civilians Max, Foreigners Min, Foreigners Max, Total Died Min, Total Died Max, Injured Min, Injured Max, Women/Children  , Special Mention (Site), Comments, References, Longitude, Latitude, Temperature(C), Temperature(F), year]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.head()
# Out:
#     S#                         Date   Time  \
# 0  1.0        Friday- June 18- 2004  22:00
# 1  2.0         Sunday- May 08- 2005  23:30
# 2  3.0  Thursday- December 01- 2005    NaN
# 3  4.0     Friday- January 06- 2006    NaN
# 4  5.0     Friday- January 13- 2006   3:00
#
#                                Location              City Province  \
# 0                             Near Wana  south Waziristan     FATA
# 1          Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                   Haisori- Miran Shah  North Waziristan     FATA
# 3  Saidgai village- 115km north of Wana  North Waziristan     FATA
# 4                      Damadola Village    Bajaur  Agency     FATA
#
#    No of Strike  AlQaeda  Taliban  Civilians Min  ...  Injured Max  \
# 0           1.0      NaN      1.0            0.0  ...          NaN
# 1           1.0      1.0      NaN            0.0  ...          NaN
# 2           1.0      1.0      NaN            0.0  ...          2.0
# ...

# %%
data['year'].isna().sum()
# Out:
# 0

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#     S#                         Date   Time  \
# 0  1.0        Friday- June 18- 2004  22:00
# 1  2.0         Sunday- May 08- 2005  23:30
# 2  3.0  Thursday- December 01- 2005    NaN
# 3  4.0     Friday- January 06- 2006    NaN
# 4  5.0     Friday- January 13- 2006   3:00
#
#                                Location              City Province  \
# 0                             Near Wana  south Waziristan     FATA
# 1          Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                   Haisori- Miran Shah  North Waziristan     FATA
# 3  Saidgai village- 115km north of Wana  North Waziristan     FATA
# 4                      Damadola Village    Bajaur  Agency     FATA
#
#    No of Strike  AlQaeda  Taliban  Civilians Min  Civilians Max  \
# 0           1.0      NaN      1.0            0.0            4.0
# 1           1.0      1.0      NaN            0.0            1.0
# 2           1.0      1.0      NaN            0.0            1.0
# ...

# %%
data['year'].max()
# Out:
# 2017.0

# %%
data['year'].min()
# Out:
# 2004.0

# %%
data.loc[((data.year >=2005) & (data.year == 2017)) | (data['Total Died Min'].value_counts()) | (data['Total Died Max'].value_counts())]
# Out:
#         S#                           Date   Time  \
# 0      1.0          Friday- June 18- 2004  22:00
# 1      2.0           Sunday- May 08- 2005  23:30
# 2      3.0    Thursday- December 01- 2005    NaN
# 3      4.0       Friday- January 06- 2006    NaN
# 4      5.0       Friday- January 13- 2006   3:00
# 5      6.0       Monday- October 30- 2006    NaN
# 6      7.0         Friday- April 27- 2007    NaN
# 7      8.0         Tuesday- June 19- 2007  10:30
# 8      9.0      Friday- November 02- 2007    NaN
# 9     10.0      Monday- December 03- 2007    NaN
# 10    11.0      Tuesday- January 29- 2008   4:00
# 11    12.0    Thursday- February 28- 2008   2:00
# 12    13.0         Sunday- March 16- 2008  15:35
# 13    14.0        Tuesday- April 01- 2008    NaN
# 14    15.0        Wednesday- May 14- 2008  20:00
# 15    16.0        Saturday- June 14- 2008    NaN
# 16    17.0          Monday- July 28- 2008    NaN
# 17    18.0     Wednesday- August 13- 2008  20:30
# ...

# %%
data.loc[(data.AlQaeda == 1.0) | (data.Taliban >= 1.0)]
# Out:
#         S#                           Date   Time  \
# 0      1.0          Friday- June 18- 2004  22:00
# 1      2.0           Sunday- May 08- 2005  23:30
# 2      3.0    Thursday- December 01- 2005    NaN
# 10    11.0      Tuesday- January 29- 2008   4:00
# 14    15.0        Wednesday- May 14- 2008  20:00
# 16    17.0          Monday- July 28- 2008    NaN
# 24    25.0     Monday- September 08- 2008  10:20
# 30    31.0     Saturday- October 11- 2008    NaN
# 34    35.0       Friday- October 31- 2008    NaN
# 35    36.0       Friday- October 31- 2008    NaN
# 36    37.0      Friday- November 07- 2008  10:00
# 46    47.0     Thursday- January 01- 2009    NaN
# 48    49.0       Friday- January 23- 2009  17:00
# 49    50.0    Saturday- February 14- 2009   7:45
# 58    59.0      Wednesday- April 08- 2009    NaN
# 63    64.0         Saturday- May 16- 2009   8:00
# 71    72.0          Friday- July 17- 2009  16:00
# 72    73.0     Wednesday- August 05- 2009    NaN
# ...

# %%
data['year'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-082de536b779> in <module>
# ----> 1 data['year'].max()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
data['year'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-f3d193b878a9> in <module>
# ----> 1 data['year'].min()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
data["year"]= pd.to_datetime(data["Date"])
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-37286406234b> in <module>
# ----> 1 data["year"]= pd.to_datetime(data["Date"])
#       2 data.head()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
list(data.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-11a68b015844> in <module>
# ----> 1 list(data.columns)
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
data.isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-156-4e7d41c2f5e0> in <module>
# ----> 1 data.isnull()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
data['City'].value_counts()

# %%
data2.sort_values("", ascending= False)
