# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
omnibus = pd.read_csv("omnibuslaw_videos.csv")
washingtonpost = pd.read_csv("washingtonpost_videos.csv")
trending = pd.read_csv("trending.csv")
tiktokliked = pd.read_csv("tiktok_liked_videos.csv")

# %%
omnibus.head()
# Out:
#                user_id             video_id  \
# 0  6582720000000000000  6881240000000000000
# 1  6565720000000000000  6880400000000000000
# 2  6549920000000000000  6880840000000000000
# 3  6868290000000000000  6880390000000000000
# 4  6861840000000000000  6880860000000000000
#
#                                           video_desc        createTime  \
# 0  😭😂🤣🤣🤣#staysafe #gagalkanomnibuslaw #stayhealth...  08/10/2020 20:28
# 1   #gagalkanomnibuslaw #tolakomnibuslaw #omnibuslaw  06/10/2020 13:49
# 2  Setujuu. No debat!! #omnibuslaw #tolakruucipta...  07/10/2020 18:37
# 3  Kalau suara wakil rakyat yang kontra aja bisa ...  06/10/2020 13:38
# 4  Waduh Ditangkap kenapa ya ? ada yg tau kejadia...  07/10/2020 20:05
#
#                                         video_length  \
# 0  {'width': 576, 'height': 1040, 'ratio': 52, 'd...
# 1  {'width': 540, 'height': 900, 'ratio': 12, 'du...
# 2  {'width': 540, 'height': 960, 'ratio': 33, 'du...
# ...

# %%
omnibus.describe()
# Out:
#             user_id      video_id       n_likes       n_shares    n_comments  \
# count  1.000000e+01  1.000000e+01  1.000000e+01      10.000000     10.000000
# mean   6.728710e+18  6.881007e+18  1.144300e+06   35440.000000  19966.900000
# std    1.454835e+17  4.108812e+14  3.957884e+05   36202.952611  10192.110265
# min    6.549920e+18  6.880390e+18  7.670000e+05   10600.000000   3969.000000
# 25%    6.569970e+18  6.880832e+18  9.838250e+05   15025.000000  12275.000000
# 50%    6.794175e+18  6.881050e+18  9.951000e+05   19300.000000  19750.000000
# 75%    6.859000e+18  6.881280e+18  1.300000e+06   31500.000000  28625.000000
# max    6.868290e+18  6.881630e+18  2.100000e+06  115700.000000  33600.000000
#
#             n_plays
# count  1.000000e+01
# mean   9.000000e+06
# std    5.663725e+06
# min    3.300000e+06
# 25%    4.475000e+06
# 50%    6.850000e+06
# 75%    1.295000e+07
# max    1.980000e+07

# %%
omnibus.shape
# Out:
# (10, 10)

# %%
omnibus.columns
# Out:
# Index(['user_id', 'video_id', 'video_desc', 'createTime', 'video_length',
#        'video_link', 'n_likes', 'n_shares', 'n_comments', 'n_plays'],
#       dtype='object')

# %%
pd.options.display.float_format = "{:,.5f}".format

# %%
omnibus.head(10)
# Out:
#                user_id             video_id  \
# 0  6582720000000000000  6881240000000000000
# 1  6565720000000000000  6880400000000000000
# 2  6549920000000000000  6880840000000000000
# 3  6868290000000000000  6880390000000000000
# 4  6861840000000000000  6880860000000000000
# 5  6865980000000000000  6881280000000000000
# 6  6776820000000000000  6881320000000000000
# 7  6553800000000000000  6881630000000000000
# 8  6811530000000000000  6880830000000000000
# 9  6850480000000000000  6881280000000000000
#
#                                           video_desc        createTime  \
# 0  😭😂🤣🤣🤣#staysafe #gagalkanomnibuslaw #stayhealth...  08/10/2020 20:28
# 1   #gagalkanomnibuslaw #tolakomnibuslaw #omnibuslaw  06/10/2020 13:49
# 2  Setujuu. No debat!! #omnibuslaw #tolakruucipta...  07/10/2020 18:37
# 3  Kalau suara wakil rakyat yang kontra aja bisa ...  06/10/2020 13:38
# 4  Waduh Ditangkap kenapa ya ? ada yg tau kejadia...  07/10/2020 20:05
# ...

# %%
omnibus["video_desc"] =omnibus["video_desc"].str.split(',')
