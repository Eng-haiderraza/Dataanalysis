# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("matches.csv")

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.isnull()
# Out:
#         id  Season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# 5    False   False  False  False  False  False        False          False
# 6    False   False  False  False  False  False        False          False
# 7    False   False  False  False  False  False        False          False
# 8    False   False  False  False  False  False        False          False
# 9    False   False  False  False  False  False        False          False
# 10   False   False  False  False  False  False        False          False
# ...

# %%
data['team1'].isna().sum()
# Out:
# 0

# %%
data['toss_decision'].isna().sum()
# Out:
# 0

# %%
data['team2'].isna().sum()
# Out:
# 0

# %%
data['city'].isna().sum()
# Out:
# 7

# %%
data['toss_winner'].isna().sum()
# Out:
# 0

# %%
data['result'].isna().sum()
# Out:
# 0

# %%
data['dl_applied'].isna().sum()
# Out:
# 0

# %%
data['winner'].isna().sum()
# Out:
# 4

# %%
data['win_by_runs'].isna().sum()
# Out:
# 0

# %%
data['win_by_wickets'].isna().sum()
# Out:
# 0

# %%
data['player_of_match'].isna().sum()
# Out:
# 4

# %%
data['venue'].isna().sum()
# Out:
# 0

# %%
data['umpire1'].isna().sum()
# Out:
# 2

# %%
data['umpire2'].isna().sum()
# Out:
# 2

# %%
data['umpire3'].isna().sum()
# Out:
# 637

# %%
data['umpire3'] = data['umpire3'].fillna(0)

# %%
data['umpire3'].isna().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
data["toss_decision"].count()
#count of no of matches
# Out:
# 756

# %%
data1 = (data.team1.value_counts() + data.team2.value_counts())
data1
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %%
data['player_of_match'].describe()
# Out:
# count          752
# unique         226
# top       CH Gayle
# freq            21
# Name: player_of_match, dtype: object

# %%
data['player_of_match'].value_counts()[0:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# Name: player_of_match, dtype: int64

# %%
winbybattingfirst = [(data.win_by_wickets == 0) & (data.result == 0)]
#add this column at end and then get values
#data.insert(19,"win_by_bat",winbybattingfirst, True)

# %%
data.loc[((data.team1 == data.toss_winner) | (data.team2 == data.toss_winner)) & (data.toss_decision == "bat") &( (data.winner == data.team1)| (data.winner == data.team2))]
# Out:
#         id    Season           city        date                        team1  \
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# 14      15  IPL-2017          Delhi  15-04-2017             Delhi Daredevils
# 17      18  IPL-2017          Delhi  17-04-2017             Delhi Daredevils
# 20      21  IPL-2017      Hyderabad  19-04-2017          Sunrisers Hyderabad
# 33      34  IPL-2017         Rajkot  29-04-2017                Gujarat Lions
# 36      37  IPL-2017         Mumbai  01-05-2017  Royal Challengers Bangalore
# 46      47  IPL-2017      Hyderabad  08-05-2017               Mumbai Indians
# 50      51  IPL-2017          Delhi  12-05-2017             Delhi Daredevils
# 54      55  IPL-2017          Delhi  14-05-2017  Royal Challengers Bangalore
# 58      59  IPL-2017      Hyderabad  21-05-2017               Mumbai Indians
# ...

# %%
data.loc[((data.team1 == data.toss_winner) | (data.team2 == data.toss_winner)) & (data.toss_decision == "field") &( (data.winner == data.team1)| (data.winner == data.team2))]
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 5        6  IPL-2017      Hyderabad  09-04-2017                Gujarat Lions
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 8        9  IPL-2017           Pune  11-04-2017             Delhi Daredevils
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# 10      11  IPL-2017        Kolkata  13-04-2017              Kings XI Punjab
# 11      12  IPL-2017      Bangalore  14-04-2017  Royal Challengers Bangalore
# 12      13  IPL-2017         Rajkot  14-04-2017       Rising Pune Supergiant
# ...

# %%
data_battingfirst = data[data['win_by_runs'] > 0]
data_battingfirst.shape
# Out:
# (337, 18)

# %%
data_battingfirst = data[data['win_by_wickets'] > 0]
data_battingfirst.shape
# Out:
# (406, 18)

# %%
data['Season'].value_counts()
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2019    60
# IPL-2018    60
# IPL-2010    60
# IPL-2016    60
# IPL-2014    60
# IPL-2015    59
# IPL-2017    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
data.sort_values("win_by_runs", ascending = False)
# Out:
#         id    Season            city        date                        team1  \
# 43      44  IPL-2017           Delhi  06-05-2017               Mumbai Indians
# 619    620  IPL-2016       Bangalore  14-05-2016  Royal Challengers Bangalore
# 59      60  IPL-2008       Bangalore  18-04-2008        Kolkata Knight Riders
# 556    557  IPL-2015       Bangalore  06-05-2015  Royal Challengers Bangalore
# 410    411  IPL-2013       Bangalore  23-04-2013  Royal Challengers Bangalore
# 706  11147  IPL-2019       Hyderabad  31-03-2019          Sunrisers Hyderabad
# 295    296  IPL-2011      Dharamsala  17-05-2011              Kings XI Punjab
# 114    115  IPL-2008          Mumbai  30-05-2008             Rajasthan Royals
# 676   7934  IPL-2018         Kolkata  09-05-2018               Mumbai Indians
# 182    183  IPL-2010           Delhi  17-03-2010               Mumbai Indians
# 8        9  IPL-2017            Pune  11-04-2017             Delhi Daredevils
# ...

# %%
data["winner"].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
data["winner"].value_counts().keys()[0:5]
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab'],
#       dtype='object')

# %%
data["winner"].value_counts()[0:5]
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(12,4))
plt.bar(list(data["winner"].value_counts().keys()[0:5]),list(data["winner"].value_counts()[0:5]),color = 'r')
plt.title("Teams VS Runs",fontsize=14, fontweight = "bold")
plt.xlabel("Team")
plt.ylabel("Runs")
# Out:
# Text(0, 0.5, 'Runs')
